# %%
# !get clone https://github.com/huridocs/pdf-document-layout-analysis.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install Requirements

# %% [markdown]
# ### Download model

# %% [markdown]
# **Jika model belum terdownload, jalankan baris Download model**
#
# **Code download_models.py ada di directory "src"**
#
# **Pastikan model berada pada path pdf-document-layout-analysis/models**

# %%
# !pwd

# %%
##Download model

# !python /content/drive/MyDrive/pdf-document-layout-analysis/src/download_models.py

# %% [markdown]
# ### python library

# %%
import os
os.chdir("/content/drive/MyDrive/doc_processing/pdf-document-layout-analysis")

# %%
# !pip list

# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-yac9si26
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-yac9si26
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 9604f5995cc628619f0e4fd913453b4d7d61db3f
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.4 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/doc_processing/pdf-document-layout-analysis")

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/UniModal4Reasoning/StructEqTable-Deploy.git (to revision fd06078bfa9364849eb39330c075dd63cbed73ff) to /tmp/pip-req-build-a8s2n64k
#   Running command git clone --filter=blob:none --quiet https://github.com/UniModal4Reasoning/StructEqTable-Deploy.git /tmp/pip-req-build-a8s2n64k
#   Running command git rev-parse -q --verify 'sha^fd06078bfa9364849eb39330c075dd63cbed73ff'
#   Running command git fetch -q https://github.com/UniModal4Reasoning/StructEqTable-Deploy.git fd06078bfa9364849eb39330c075dd63cbed73ff
#   Running command git checkout -q fd06078bfa9364849eb39330c075dd63cbed73ff
#   Resolved https://github.com/UniModal4Reasoning/StructEqTable-Deploy.git to commit fd06078bfa9364849eb39330c075dd63cbed73ff
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !pip install dask[dataframe]
# Out:
# ...
# INFO: pip is looking at multiple versions of dask-expr to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 2.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### linux package

# %%
# !sudo apt update
# !sudo apt install qpdf -y
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 257 kB in 2s (129 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 21 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...

# %%
# !sudo apt update
# !sudo apt install poppler-utils -y
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 21 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...

# %%
# !apt-get install --fix-missing -y -q --no-install-recommends libgomp1 ffmpeg libsm6 libxext6 pdftohtml git ninja-build g++ qpdf pandoc
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# g++ is already the newest version (4:11.2.0-1ubuntu1).
# libsm6 is already the newest version (2:1.2.3-1build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# ninja-build is already the newest version (1.10.1-1).
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# qpdf is already the newest version (10.6.3-1).
# git is already the newest version (1:2.34.1-1ubuntu1.12).
# libgomp1 is already the newest version (12.3.0-1ubuntu1~22.04).
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %%
# !apt-get install -y ocrmypdf tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ocrmypdf is already the newest version (13.4.0+dfsg-1).
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %% [markdown]
# ## Running pdf-document-layout-analysis

# %% [markdown]
# **Pekerjaan dilakukan di direktori "src"**

# %%
import os
os.chdir("/content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/src")

# %%
from pdf_layout_analysis.get_xml import get_xml
from pdf_layout_analysis.run_pdf_layout_analysis import analyze_pdf
from pdf_layout_analysis.run_pdf_layout_analysis_fast import analyze_pdf_fast
from text_extraction.get_text_extraction import get_text_extraction
from toc.get_toc import get_toc
from visualization.get_visualization import get_visualization
# Out:
# 2025-02-13 09:17:39,785 [INFO] NumExpr defaulting to 2 threads.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/src

# %%
from pathlib import Path
from pathlib import Path
import os

current_dir = Path.cwd()
base_dir = os.path.dirname(current_dir)
# print(base_dir)

pdf_path_chunk = os.path.join(base_dir,"sample_adira","sample_page_27.pdf")

print(pdf_path_chunk)
# Out:
# /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/sample_adira/sample_page_27.pdf

# %%
sample_adira_dir = os.path.join(base_dir,"sample_adira")
print(sample_adira_dir)
# Out:
# /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/sample_adira

# %% [markdown]
# ### Fast Process

# %%
from pathlib import Path
from tempfile import gettempdir
from starlette.responses import FileResponse
from pdf_layout_analysis.run_pdf_layout_analysis_fast import analyze_pdf_fast
from visualization.save_output_to_pdf import save_output_to_pdf
from glob import glob
from os.path import getctime, join



file_content_fast = Path(pdf_path_chunk).read_bytes()
segment_boxes_fast = analyze_pdf_fast(file_content_fast)
pdf_path_fast = max(glob(join(gettempdir(), "*.pdf")), key=getctime)
save_output_to_pdf(pdf_path_fast, segment_boxes_fast)
# Out:
# 2025-02-13 09:28:38,457 [INFO] Creating Paragraph Tokens [fast]
# ...
# 100%|██████████| 1/1 [00:00<00:00, 724.78it/s]

# %%
pdf_path_fast
# Out:
# '/tmp/e7efa70e-e9ec-11ef-9002-0242ac1c000c.pdf'

# %%
name_fast_pdf_result = "analyze_fast_result.pdf"
target_copy_fast = os.path.join(sample_adira_dir, name_fast_pdf_result)
print(target_copy_fast)
# Out:
# /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/sample_adira/analyze_fast_result.pdf

# %%
# !cp {pdf_path_fast} {target_copy_fast}

# %%
# !pip install pymupdf
# Out:
# ...
# WARNING: Error parsing dependencies of pdfminer-six: Invalid version: '-VERSION-'

# %%
import fitz
import matplotlib.pyplot as plt
from PIL import Image
import io

pdf_path_copy = target_copy_fast

doc = fitz.open(pdf_path_copy)
page = doc[0]

pix = page.get_pixmap(dpi=150)
img_bytes = pix.tobytes("png")
img = Image.open(io.BytesIO(img_bytes))
fig, ax = plt.subplots(figsize=(24, 12))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Normal Process

# %%
from pathlib import Path
from tempfile import gettempdir
from fastapi import UploadFile
from starlette.responses import FileResponse
from pdf_layout_analysis.run_pdf_layout_analysis import analyze_pdf
from visualization.save_output_to_pdf import save_output_to_pdf
from glob import glob
from os.path import getctime, join



file_content_normal = Path(pdf_path_chunk).read_bytes()
segment_boxes_normal = analyze_pdf(file_content_normal, "")
pdf_path_normal = max(glob(join(gettempdir(), "*.pdf")), key=getctime)
save_output_to_pdf(pdf_path_normal, segment_boxes_normal)
# Out:
# 2025-02-13 09:34:27,101 [INFO] Creating PDF images
# 2025-02-13 09:34:27,450 [INFO] Full TransformGens used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')], crop: None
# WARNING [02/13 09:34:27 d2.data.datasets.coco]: /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/jsons/test.json contains 259 annotations, but only 0 of them match to images in the file.
# [02/13 09:34:27 d2.data.datasets.coco]: Loaded 1 images in COCO format from /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/jsons/test.json
# [02/13 09:34:27 d2.data.build]: Distribution of instances among all 11 categories:
# |  category  | #instances   |   category    | #instances   |  category   | #instances   |
# |:----------:|:-------------|:-------------:|:-------------|:-----------:|:-------------|
# |  Caption   | 0            |   Footnote    | 0            |   Formula   | 0            |
# ...

# %%
pdf_path_normal
# Out:
# '/tmp/b7be7834-e9ed-11ef-9002-0242ac1c000c.pdf'

# %%
name_normal_pdf_result = "analyze_normal_result.pdf"
target_copy_normal = os.path.join(sample_adira_dir, name_normal_pdf_result)
print(target_copy_normal)
# Out:
# /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/sample_adira/analyze_normal_result.pdf

# %%
# !cp {pdf_path_normal} {target_copy_normal}

# %%
segment_boxes_normal
# Out:
# [{'left': 205.0,
#   'top': 21.0,
#   'width': 202.0,
#   'height': 9.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
#   'text': 'PT ADIRA DINAMIKA MULTI FINANCE Tbk',
#   'type': 'Section header'},
#  {'left': 51.0,
#   'top': 49.0,
#   'width': 238.0,
#   'height': 51.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
#   'text': 'CATATAN ATAS LAPORAN KEUANGAN Pada tanggal 31 Desember 2023 dan 2022, untuk tahun-tahun yang berakhir pada tanggal tersebut (Disajikan dalam jutaan Rupiah, kecuali dinyatakan lain)',
#   'type': 'Section header'},
#  {'left': 377.0,
#   'top': 49.0,
#   'width': 182.0,
#   'height': 52.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
#   'text': 'NOTES TO THE FINANCIAL STATEMENTS As of 31 December 2023 and 2022, for the years then ended (Expressed in millions of Rupiah, unless otherwise stated)',
#   'type': 'Section header'},
#  {'left': 58.0,
#   'top': 774.0,
#   'width': 53.0,
# ...

# %%
import fitz
import matplotlib.pyplot as plt
from PIL import Image
import io

pdf_path_copy = pdf_path_normal

doc = fitz.open(pdf_path_copy)

# Ambil halaman pertama
page = doc[0]

# Konversi halaman ke gambar
pix = page.get_pixmap(dpi=150)
img_bytes = pix.tobytes("png")  # Simpan sebagai byte

# Konversi byte menjadi gambar PIL
img = Image.open(io.BytesIO(img_bytes))
fig, ax = plt.subplots(figsize=(24, 12))
# Tampilkan gambar dengan Matplotlib
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# **extract Table of Content**

# %%
from toc.extract_table_of_contents import extract_table_of_contents
extract_TOC_result =  extract_table_of_contents(file_content_normal, segment_boxes_normal)
# Out:
# 2025-02-13 09:49:04,208 [INFO] Getting TOC

# %%
extract_TOC_result
# Out:
# [{'indentation': 0,
#   'label': 'PT ADIRA DINAMIKA MULTI FINANCE Tbk',
#   'bounding_box': {'left': 205,
#    'top': 21,
#    'width': 202,
#    'height': 9,
#    'page': '1'}},
#  {'indentation': 0,
#   'label': 'CATATAN ATAS LAPORAN KEUANGAN Pada tanggal 31 Desember 2023 dan 2022, untuk tahun-tahun yang berakhir pada tanggal tersebut (Disajikan dalam jutaan Rupiah, kecuali dinyatakan lain)',
#   'bounding_box': {'left': 51,
#    'top': 49,
#    'width': 238,
#    'height': 51,
#    'page': '1'}},
#  {'indentation': 0,
#   'label': 'NOTES TO THE FINANCIAL STATEMENTS As of 31 December 2023 and 2022, for the years then ended (Expressed in millions of Rupiah, unless otherwise stated)',
#   'bounding_box': {'left': 377,
#    'top': 49,
#    'width': 182,
#    'height': 52,
#    'page': '1'}},
#  {'indentation': 1,
#   'label': '1.  INFORMASI UMUM (lanjutan)',
#   'bounding_box': {'left': 51,
#    'top': 113,
#    'width': 136,
#    'height': 8,
#    'page': '1'}},
# ...

# %% [markdown]
# ### Analyze pdf markdown

# %% [markdown]
# **hasil output tidak ada perbedaan dengan proses normal**

# %%
# from pathlib import Path
# from tempfile import gettempdir
# from fastapi import UploadFile
# from starlette.responses import FileResponse
# from pdf_layout_analysis.run_pdf_layout_analysis import analyze_pdf
# from visualization.save_output_to_pdf import save_output_to_pdf
# from glob import glob
# from os.path import getctime, join



# file_content = Path(pdf_path_chunk).read_bytes()
# segment_boxes = analyze_pdf(file_content, "", "markdown")
# pdf_path = max(glob(join(gettempdir(), "*.pdf")), key=getctime)
# save_output_to_pdf(pdf_path, segment_boxes)
# file_response = FileResponse(pdf_path, media_type="application/pdf", filename=Path(pdf_path).name)

# %%
# segment_boxes

# %% [markdown]
# ### Full PDF Process

# %%
from pathlib import Path
from tempfile import gettempdir
from fastapi import UploadFile
from starlette.responses import FileResponse
from pdf_layout_analysis.run_pdf_layout_analysis import analyze_pdf
from visualization.save_output_to_pdf import save_output_to_pdf
from glob import glob
from os.path import getctime, join

full_pdf_path = os.path.join(sample_adira_dir, "ADMF-LK-31-Desember-2023.pdf")


file_content_full = Path(full_pdf_path).read_bytes()
segment_boxes_full = analyze_pdf(file_content_full, "")
pdf_path_output_full = max(glob(join(gettempdir(), "*.pdf")), key=getctime)
save_output_to_pdf(pdf_path_output_full, segment_boxes_full)
# Out:
# 2025-02-13 09:39:02,325 [INFO] Creating PDF images
# 2025-02-13 09:39:49,760 [INFO] Full TransformGens used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')], crop: None
# WARNING [02/13 09:39:49 d2.data.datasets.coco]: /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/jsons/test.json contains 23990 annotations, but only 0 of them match to images in the file.
# [02/13 09:39:49 d2.data.datasets.coco]: Loaded 152 images in COCO format from /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/jsons/test.json
# [02/13 09:39:49 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/13 09:39:49 d2.data.common]: Serializing 152 elements to byte tensors and concatenating them all ...
# [02/13 09:39:49 d2.data.common]: Serialized dataset takes 0.03 MiB
# ...

# %%
pdf_path_output_full
# Out:
# '/tmp/5bc9bfc4-e9ee-11ef-9002-0242ac1c000c.pdf'

# %%
name_full_pdf_result = "analyze_full_result.pdf"
target_copy_full = os.path.join(sample_adira_dir, name_full_pdf_result)
print(target_copy_full)
# Out:
# /content/drive/MyDrive/doc_processing/pdf-document-layout-analysis/sample_adira/analyze_full_result.pdf

# %%
# !cp {pdf_path_output_full} {target_copy_full}

# %%
segment_boxes_full
# Out:
# [{'left': 128.0,
#   'top': 770.0,
#   'width': 53.0,
#   'height': 8.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
#   'text': '* Tidak diaudit',
#   'type': 'Text'},
#  {'left': 581.0,
#   'top': 770.0,
#   'width': 40.0,
#   'height': 8.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
#   'text': '*Unaudited',
#   'type': 'Text'},
#  {'left': 127.0,
#   'top': 189.0,
#   'width': 323.0,
#   'height': 14.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
#   'text': 'PT ADIRA DINAMIKA MULTI FINANCE Tbk',
#   'type': 'Section header'},
#  {'left': 125.0,
#   'top': 223.0,
#   'width': 335.0,
#   'height': 134.0,
#   'page_number': 1,
#   'page_width': 595,
#   'page_height': 841,
# ...
